# %% [markdown]
# ## Read processed 10K and 10Q data from CSV

# %%
import os 
import pandas as pd
currentDirectory = os.getcwd()
filename = currentDirectory + '/data_10k10q.csv'

base_df = pd.read_csv(filename,sep="|")

# %%
base_df.head()
# Out:
#   company     cik             file_name doc_type  file_date  conformed_period  \
# 0     HON  773840  0000773840-20-000009     10-K   20200214          20191231
# 1     HON  773840  0000930413-18-000292     10-K   20180209          20171231
# 2     HON  773840  0000930413-19-000366     10-K   20190208          20181231
# 3     HON  773840  0000773840-22-000018     10-K   20220211          20211231
# 4    INTC   50863  0000050863-19-000007     10-K   20190201          20181229
#
#    bag_len                                            content
# 0     4368  ['intended', 'help', 'reader', 'understand', '...
# 1     5375  ['intended', 'help', 'reader', 'understand', '...
# 2     5106  ['intended', 'help', 'reader', 'understand', '...
# 3     4569  ['income', 'attributable', 'honeywell', 'compa...
# 4     5427  ['five', 'years', 'strategy', 'transform', 'ce...

# %%
base_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 268 entries, 0 to 267
# Data columns (total 10 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   company           268 non-null    object
#  1   cik               268 non-null    int64
#  2   file_name         268 non-null    object
#  3   doc_type          268 non-null    object
#  4   file_date         268 non-null    int64
#  5   conformed_period  268 non-null    int64
#  6   bag_len           268 non-null    int64
#  7   content           268 non-null    object
#  8   close_price       268 non-null    float64
#  9   close_price_20    268 non-null    float64
# dtypes: float64(2), int64(4), object(4)
# memory usage: 21.1+ KB

# %% [markdown]
# ## Get Close price data

# %%
from datetime import datetime
from datetime import timedelta
import yfinance as yf
import matplotlib.pyplot as plt

base_df['close_price'] = 0.0 
base_df['close_price_20'] = 0.0 
for index, row in base_df.iterrows():
    #print(row)
    #print(int(str(row['file_date'])[0:4]))
    print(row['company'] + ': ' + str(row['file_date']))
    year = int(str(row['file_date'])[0:4])
    month = int(str(row['file_date'])[4:6])
    day = int(str(row['file_date'])[6:8])
    start_date = datetime(year, month, day)
    end_date = datetime(year, month, day) + timedelta(days=1)
    
    data = yf.download(row['company'], start = start_date, end = end_date)
    if len(data) != 0:
        base_df['close_price'][index] = data['Close'][0]
    else: 
        base_df['close_price'][index] = 0
    start_date = datetime(year, month, day) + timedelta(days=20)
    end_date = datetime(year, month, day) + timedelta(days=21)
    data = yf.download(row['company'], start = start_date, end = end_date)
    if len(data) != 0:
        base_df['close_price_20'][index] = data['Close'][0]
    else:
        base_df['close_price_20'][index] = 0
    #print(data)
# Out:
# HON: 20200214
# [*********************100%***********************]  1 of 1 completed
# /Users/wailunchung/.pyenv/versions/3.7.3/lib/python3.7/site-packages/ipykernel_launcher.py:20: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# [*********************100%***********************]  1 of 1 completed
# HON: 20180209
# /Users/wailunchung/.pyenv/versions/3.7.3/lib/python3.7/site-packages/ipykernel_launcher.py:27: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# HON: 20190208
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# HON: 20220211
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# INTC: 20190201
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# VZ: 20210225
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# VZ: 20220211
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# MMM: 20160802
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# MMM: 20160503
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# MMM: 20190726
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# MMM: 20191025
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# AXP: 20191021
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
#
# 1 Failed download:
# - AXP: No data found for this date range, symbol may be delisted
# AXP: 20161025
# /Users/wailunchung/.pyenv/versions/3.7.3/lib/python3.7/site-packages/ipykernel_launcher.py:29: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# AXP: 20210723
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# AXP: 20200724
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# AXP: 20210423
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# AXP: 20181023
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# AXP: 20211022
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# AXP: 20200424
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# AXP: 20201023
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# AXP: 20190723
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# AMGN: 20191030
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# AMGN: 20160502
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
#
# 1 Failed download:
# - AMGN: No data found for this date range, symbol may be delisted
# AMGN: 20170427
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# AMGN: 20201029
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# AMGN: 20190731
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# AMGN: 20181031
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# AMGN: 20190501
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# AMGN: 20180727
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# AMGN: 20210428
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# AMGN: 20160729
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# AAPL: 20170201
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# AAPL: 20210728
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# AAPL: 20170802
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# AAPL: 
# [268 rows x 10 columns]

# %%
df_price = base_df[(base_df.close_price > 0) & (base_df.close_price_20 > 0 )]

# %%
df_price
# Out:
#     company      cik             file_name doc_type  file_date  \
# 0       HON   773840  0000773840-20-000009     10-K   20200214
# 1       HON   773840  0000930413-18-000292     10-K   20180209
# 2       HON   773840  0000930413-19-000366     10-K   20190208
# 3       HON   773840  0000773840-22-000018     10-K   20220211
# 4      INTC    50863  0000050863-19-000007     10-K   20190201
# ..      ...      ...                   ...      ...        ...
# 263     DIS  1744489  0001744489-21-000108     10-K   20210513
# 264     DIS  1744489  0001744489-19-000167     10-K   20190806
# 265     DIS  1744489  0001744489-21-000047     10-K   20210211
# 266     DIS  1744489  0001744489-22-000059     10-K   20220209
# 267     DIS  1744489  0001744489-21-000181     10-K   20210812
#
#      conformed_period  bag_len  \
# 0            20191231     4368
# 1            20171231     5375
# 2            20181231     5106
# 3            20211231     4569
# 4            20181229     5427
# ..                ...      ...
# 263          20210403     9165
# 264          20190629     7905
# 265          20210102     6200
# 266          20220101     7051
# 267          20210703     9270
#
#                                                content  close_price  \
# 0    ['intended', 'help', 'reader', 'understand', '...   180.809998
# 1    ['intended', 'help', 'reader', 'understand', '...   141.754654
# 2    ['intended', 'help', 'reader', 'understand', '...   148.610001
# 3    ['income', 'attributable', 'honeywell', 'compa...   186.990005
# 4    ['five', 'years', 'strategy', 'transform', 'ce...    48.730000
# ..                                                 ...          ...
# 263  ['organization', 'informationmanagement', 'dis...   178.339996
# 264  ['organization', 'informationmanagement', 'dis...   141.869995
# 265  ['organization', 'informationmanagement', 'dis...   190.910004
# 266  ['quarterly', 'report', 'form', 'contains', 'f...   147.229996
# 267  ['organization', 'informationmanagement', 'dis...   179.289993
#
#      close_price_20
# 0        164.919998
# 1        141.093323
# 2        154.070007
# 3        187.520004
# 4         51.410000
# ..              ...
# 263      177.000000
# 264      134.610001
# 265      192.259995
# 266      145.699997
# 267      183.479996
#
# [242 rows x 10 columns]

# %% [markdown]
# ## save csv

# %%
df_price.to_csv('data_10k10q_price.csv', sep='|',index=False)

# %%
20191021
start_date = datetime(2019, 10, 21) + timedelta(days=20)
end_date = datetime(2019, 10, 21) + timedelta(days=21)
print(start_date)
print(end_date)

data = yf.download('AXP', start = '2019-11-10', end = '2019-11-11')
# Out:
# 2019-11-10 00:00:00
# 2019-11-11 00:00:00
# [*********************100%***********************]  1 of 1 completed
#
# 1 Failed download:
# - AXP: No data found for this date range, symbol may be delisted

# %%
len(data )
# Out:
# 0

# %%
## test ##

# %%
print(base_df['file_date'][0])
ss = base_df['file_date'][0].astype(str)
print(int(base_df['file_date'][0].astype(str)[0:4]))
print(base_df['file_date'][0].astype(str)[4:6])
print(base_df['file_date'][0].astype(str)[6:8])
# Out:
# 20200214
# 2020
# 02
# 14

# %%
dow30 = ['AAPL','AMGN','AXP','BA','CAT','CRM','CSCO','CVX','DIS','DOW','GS','HD','HON','IBM','INTC','JNJ','JPM','KO','MCD','MMM','MRK','MSFT','NKE','PG','TRV','UNH','V','VZ','WBA','WMT']
from datetime import datetime
import yfinance as yf
import matplotlib.pyplot as plt
  
# initialize parameters
start_date = datetime(2019, 10, 30)
end_date = datetime(2019, 10, 31)
  
# get the data
data = yf.download('AAPL', start = start_date, end = end_date)
# Out:
# [*********************100%***********************]  1 of 1 completed

# %%
sss = data['Close'][0]

# %%
sss
# Out:
# 60.814998626708984

# %%
base_df2 =base_df

# %%
base_df2['close'] = 0

# %%
base_df2['file_date'][1]
# Out:
# 20171103

# %%
#pip install yahoo_fin

# %%
import yahoo_fin.stock_info as si

# %%
aapl_earnings_hist = si.get_earnings_history("aapl")

# %%
aapl_earnings_hist
# Out:
# [{'ticker': 'AAPL',
#   'companyshortname': 'Apple Inc',
#   'startdatetime': '2022-07-25T20:00:00.000Z',
#   'startdatetimetype': 'AMC',
#   'epsestimate': None,
#   'epsactual': None,
#   'epssurprisepct': None,
#   'timeZoneShortName': 'EST',
#   'gmtOffsetMilliSeconds': -18000000,
#   'quoteType': 'EQUITY'},
#  {'ticker': 'AAPL',
#   'companyshortname': 'Apple Inc',
#   'startdatetime': '2022-04-26T20:00:00.000Z',
#   'startdatetimetype': 'AMC',
#   'epsestimate': None,
#   'epsactual': None,
#   'epssurprisepct': None,
#   'timeZoneShortName': 'EST',
#   'gmtOffsetMilliSeconds': -18000000,
#   'quoteType': 'EQUITY'},
#  {'ticker': 'AAPL',
#   'companyshortname': 'Apple Inc',
#   'startdatetime': '2022-01-27T21:00:00.000Z',
#   'startdatetimetype': 'AMC',
#   'epsestimate': 1.89,
#   'epsactual': None,
#   'epssurprisepct': None,
#   'timeZoneShortName': 'EST',
#   'gmtOffsetMilliSeconds': -18000000,
#   'quoteType': 'EQUITY'},
#  {'ticker': 'AAPL',
#   'companyshortname': 'Apple Inc',
#   'startdatetime': '2021-10-28T16:30:00.000Z',
#   'startdatetimetype': 'TAS',
#   'epsestimate': 1.24,
#   'epsactual': 1.24,
#   'epssurprisepct': 0,
#   'timeZoneShortName': 'EST',
#   'gmtOffsetMilliSeconds': -18000000,
#   'quoteType': 'EQUITY'},
#  {'ticker': 'AAPL',
#   'companyshortname': 'Apple Inc.',
#   'startdatetime': '2021-10-28T00:00:00.000Z',
#   'startdatetimetype': 'TNS',
#   'epsestimate': 1.24,
#   'epsactual': 1.24,
#   'epssurprisepct': 0.32,
#   'timeZoneShortName': 'EST',
#   'gmtOffsetMilliSeconds': 0,
#   'quoteType': 'EQUITY'},
#  {'ticker': 'AAPL',
#   'companyshortname': 'Apple Inc.',
#   'startdatetime': '2021-07-27T00:00:00.000Z',
#   'startdatetimetype': 'TNS',
#   'epsestimate': 1.01,
#   'epsactual': 1.3,
#   'epssurprisepct': 29.1,
#   'timeZoneShortName': 'EST',
#   'gmtOffsetMilliSeconds': 0,
#   'quoteType': 'EQUITY'},
#  {'ticker': 'AAPL',
#   'companyshortname': 'Apple Inc.',
#   'startdatetime': '2021-04-28T00:00:00.000Z',
#   'startdatetimetype': 'TNS',
#   'epsestimate': 0.99,
#   'epsactual': 1.4,
#   'epssurprisepct': 41.84,
#   'timeZoneShortName': 'EST',
#   'gmtOffsetMilliSeconds': 0,
#   'quoteType': 'EQUITY'},
#  {'ticker': 'AAPL',
#   'companyshortname': 'Apple Inc.',
#   'startdatetime': '2021-01-27T00:00:00.000Z',
#   'startdatetimetype': 'TNS',
#   'epsestimate': 1.41,
#   'epsactual': 1.68,
#   'epssurprisepct': 18.98,
#   'timeZoneShortName': 'EST',
#   'gmtOffsetMilliSeconds': 0,
#   'quoteType': 'EQUITY'},
#  {'ticker': 'AAPL',
#   'companyshortname': 'Apple Inc.',
#   'startdatetime': '2020-10-29T00:00:00.000Z',
#   'startdatetimetype': 'TNS',
#   'epsestimate': 0.7,
#   'epsactual': 0.73,
#   'epssurprisepct': 4.29,
#   'timeZoneShortName': 'EST',
#   'gmtOffsetMilliSeconds': 0,
#   'quoteType': 'EQUITY'},
#  {'ticker': 'AAPL',
#   'companyshortname': 'Apple Inc.',
#   'startdatetime': '2020-07-30T00:00:00.000Z',
#   'startdatetimetype': 'TNS',
#   'epsestimate': 0.51,
#   'epsactual': 0.65,
#   'epssurprisepct': 26.22,
#   'timeZoneShortName': 'EST',
#   'gmtOffsetMilliSeconds': 0,
#   'quoteType': 'EQUITY'},
#  {'ticker': 'AAPL',
#   'companyshortname': 'Apple Inc.',
#   'startdatetime': '2020-04-30T00:00:00.000Z',
#   'startdatetimetype': 'TNS',
#   'epsestimate': 0.56,
#   'epsactual': 0.64,
#   'epssurprisepct': 12.92,
#   'timeZoneShortName': 'EST',
#   'gmtOffsetMilliSeconds': 0,
#   'quoteType': 'EQUITY'},
#  {'ticker': 'AAPL',
#   'companyshortname': 'Apple Inc.',
#   'startdatetime': '2020-01-28T00:00:00.000Z',
#   'startdatetimetype': 'TNS',
#   'epsestimate': 1.14,
#   'epsactual': 1.25,
#   'epssurprisepct': 9.76,
#   'timeZoneShortName': 'EST',
#   'gmtOffsetMilliSeconds': 0,
#   'quoteType': 'EQUITY'},
#  {'ticker': 'AAPL',
#   'companyshortname': 'Apple Inc.',
#   'startdatetime': '2019-10-30T00:00:00.000Z',
#   'startdatetimetype': 'TNS',
#   'epsestimate': 0.71,
#   'epsactual': 0.76,
#   'epssurprisepct': 6.76,
#   'timeZoneShortName': 'EST',
#   'gmtOffsetMilliSeconds': 0,
#   'quoteType': 'EQUITY'},
#  {'ticker': 'AAPL',
#   'companyshortname': 'Apple Inc.',
#   'startdatetime': '2019-07-30T00:00:00.000Z',
#   'startdatetimetype': 'TNS',
#   'epsestimate': 0.53,
#   'epsactual': 0.55,
#   'epssurprisepct': 3.81,
#   'timeZoneShortName': 'EST',
#   'gmtOffsetMilliSeconds': 0,
#   'quoteType': 'EQUITY'},
#  {'ticker': 'AAPL',
#   'companyshortname': 'Apple Inc.',
#   'startdatetime': '2019-04-30T00:00:00.000Z',
#   'startdatetimetype': 'TNS',
#   'epsestimate': 0.59,
#   'epsactual': 0.62,
#   'epssurprisepct': 4.24,
#   'timeZoneShortName': 'EST',
#   'gmtOffsetMilliSeconds': 0,
#   'quoteType': 'EQUITY'},
#  {'ticker': 'AAPL',
#   'companyshortname': 'Apple Inc.',
#   'startdatetime': '2019-01-29T00:00:00.000Z',
#   'startdatetimetype': 'TNS',
#   'epsestimate': 1.04,
#   'epsactual': 1.05,
#   'epssurprisepct': 0.29,
#   'timeZoneShortName': 'EST',
#   'gmtOffsetMilliSeconds': 0,
#   'quoteType': 'EQUITY'},
#  {'ticker': 'AAPL',
#   'companyshortname': 'Apple Inc.',
#   'startdatetime': '2018-11-01T00:00:00.000Z',
#   'startdatetimetype': 'TNS',
#   'epsestimate': 0.7,
#   'epsactual': 0.73,
#   'epssurprisepct': 4.6,
#   'timeZoneShortName': 'EST',
#   'gmtOffsetMilliSeconds': 0,
#   'quoteType': 'EQUITY'},
#  {'ticker': 'AAPL',
#   'companyshortname': 'Apple Inc.',
#   'startdatetime': '2018-07-31T00:00:00.000Z',
#   'startdatetimetype': 'TNS',
#   'epsestimate': 2.18,
#   'epsactual': 2.34,
#   'epssurprisepct': 7.29,
#   'timeZoneShortName': 'EST',
#   'gmtOffsetMilliSeconds': 0,
#   'quoteType': 'EQUITY'},
#  {'ticker': 'AAPL',
#   'companyshortname': 'Apple Inc.',
#   'startdatetime': '2018-05-01T00:00:00.000Z',
#   'startdatetimetype': 'TNS',
#   'epsestimate': 2.67,
#   'epsactual': 2.73,
#   'epssurprisepct': 2.13,
#   'timeZoneShortName': 'EST',
#   'gmtOffsetMilliSeconds': 0,
#   'quoteType': 'EQUITY'},
#  {'ticker': 'AAPL',
#   'companyshortname': 'Apple Inc.',
#   'startdatetime': '2018-02-01T00:00:00.000Z',
#   'startdatetimetype': 'TNS',
#   'epsestimate': 3.86,
#   'epsactual': 3.89,
#   'epssurprisepct': 0.86,
#   'timeZoneShortName': 'EST',
#   'gmtOffsetMilliSeconds': 0,
#   'quoteType': 'EQUITY'},
#  {'ticker': 'AAPL',
#   'companyshortname': 'Apple Inc.',
#   'startdatetime': '2017-11-02T00:00:00.000Z',
#   'startdatetimetype': 'TNS',
#   'epsestimate': 1.87,
#   'epsactual': 2.07,
#   'epssurprisepct': 10.87,
#   'timeZoneShortName': 'EST',
#   'gmtOffsetMilliSeconds': 0,
#   'quoteType': 'EQUITY'},
#  {'ticker': 'AAPL',
#   'companyshortname': 'Apple Inc.',
#   'startdatetime': '2017-08-01T00:00:00.000Z',
#   'startdatetimetype': 'TNS',
#   'epsestimate': 1.57,
#   'epsactual': 1.67,
#   'epssurprisepct': 6.23,
#   'timeZoneShortName': 'EST',
#   'gmtOffsetMilliSeconds': 0,
#   'quoteType': 'EQUITY'},
#  {'ticker': 'AAPL',
#   'companyshortname': 'Apple Inc.',
#   'startdatetime': '2017-05-02T00:00:00.000Z',
#   'startdatetimetype': 'TNS',
#   'epsestimate': 2.02,
#   'epsactual': 2.1,
#   'epssurprisepct': 3.96,
#   'timeZoneShortName': 'EST',
#   'gmtOffsetMilliSeconds': 0,
#   'quoteType': 'EQUITY'},
#  {'ticker': 'AAPL',
#   'companyshortname': 'Apple Inc.',
#   'startdatetime': '2017-01-31T00:00:00.000Z',
#   'startdatetimetype': 'TNS',
#   'epsestimate': 3.21,
#   'epsactual': 3.36,
#   'epssurprisepct': 4.54,
#   'timeZoneShortName': 'EST',
#   'gmtOffsetMilliSeconds': 0,
#   'quoteType': 'EQUITY'},
#  {'ticker': 'AAPL',
#   'companyshortname': 'Apple Inc.',
#   'startdatetime': '2016-10-25T00:00:00.000Z',
#   'startdatetimetype': 'TNS',
#   'epsestimate': 1.66,
#   'epsactual': 1.67,
#   'epssurprisepct': 0.85,
#   'timeZoneShortName': 'EST',
#   'gmtOffsetMilliSeconds': 0,
#   'quoteType': 'EQUITY'},
#  {'ticker': 'AAPL',
#   'companyshortname': 'Apple Inc.',
#   'startdatetime': '2016-07-26T00:00:00.000Z',
#   'startdatetimetype': 'TNS',
#   'epsestimate': 1.38,
#   'epsactual': 1.42,
#   'epssurprisepct': 2.6,
#   'timeZoneShortName': 'EST',
#   'gmtOffsetMilliSeconds': 0,
#   'quoteType': 'EQUITY'},
#  {'ticker': 'AAPL',
#   'companyshortname': 'Apple Inc.',
#   'startdatetime': '2016-04-26T00:00:00.000Z',
#   'startdatetimetype': 'TNS',
#   'epsestimate': 2,
#   'epsactual': 1.9,
#   'epssurprisepct': -4.9,
#   'timeZoneShortName': 'EST',
#   'gmtOffsetMilliSeconds': 0,
#   'quoteType': 'EQUITY'},
#  {'ticker': 'AAPL',
#   'companyshortname': 'Apple Inc.',
#   'startdatetime': '2016-01-26T00:00:00.000Z',
#   'startdatetimetype': 'TNS',
#   'epsestimate': 3.23,
#   'epsactual': 3.28,
#   'epssurprisepct': 1.64,
#   'timeZoneShortName': 'EST',
#   'gmtOffsetMilliSeconds': 0,
#   'quoteType': 'EQUITY'},
#  {'ticker': 'AAPL',
#   'companyshortname': 'Apple Inc.',
#   'startdatetime': '2015-10-27T00:00:00.000Z',
#   'startdatetimetype': 'TNS',
#   'epsestimate': 1.88,
#   'epsactual': 1.96,
#   'epssurprisepct': 4.26,
#   'timeZoneShortName': 'EST',
#   'gmtOffsetMilliSeconds': 0,
#   'quoteType': 'EQUITY'},
#  {'ticker': 'AAPL',
#   'companyshortname': 'Apple Inc.',
#   'startdatetime': '2015-07-21T00:00:00.000Z',
#   'startdatetimetype': 'TNS',
#   'epsestimate': 1.81,
#   'epsactual': 1.85,
#   'epssurprisepct': 2.15,
#   'timeZoneShortName': 'EST',
#   'gmtOffsetMilliSeconds': 0,
#   'quoteType': 'EQUITY'},
#  {'ticker': 'AAPL',
#   'companyshortname': 'Apple Inc.',
#   'startdatetime': '2015-04-27T00:00:00.000Z',
#   'startdatetimetype': 'TNS',
#   'epsestimate': 2.16,
#   'epsactual': 2.33,
#   'epssurprisepct': 7.92,
#   'timeZoneShortName': 'EST',
#   'gmtOffsetMilliSeconds': 0,
#   'quoteType': 'EQUITY'},
#  {'ticker': 'AAPL',
#   'companyshortname': 'Apple Inc.',
#   'startdatetime': '2015-01-27T00:00:00.000Z',
#   'startdatetimetype': 'TNS',
#   'epsestimate': 2.6,
#   'epsactual': 3.06,
#   'epssurprisepct': 17.51,
#   'timeZoneShortName': 'EST',
#   'gmtOffsetMilliSeconds': 0,
#   'quoteType': 'EQUITY'},
#  {'ticker': 'AAPL',
#   'companyshortname': 'Apple Inc.',
#   'startdatetime': '2014-10-20T00:00:00.000Z',
#   'startdatetimetype': 'TNS',
#   'epsestimate': 1.31,
#   'epsactual': 1.42,
#   'epssurprisepct': 8.81,
#   'timeZoneShortName': 'EST',
#   'gmtOffsetMilliSeconds': 0,
#   'quoteType': 'EQUITY'},
#  {'ticker': 'AAPL',
#   'companyshortname': 'Apple Inc.',
#   'startdatetime': '2014-07-22T00:00:00.000Z',
#   'startdatetimetype': 'TNS',
#   'epsestimate': 1.23,
#   'epsactual': 1.28,
#   'epssurprisepct': 3.98,
#   'timeZoneShortName': 'EST',
#   'gmtOffsetMilliSeconds': 0,
#   'quoteType': 'EQUITY'},
#  {'ticker': 'AAPL',
#   'companyshortname': 'Apple Inc.',
#   'startdatetime': '2014-04-23T00:00:00.000Z',
#   'startdatetimetype': 'TNS',
#   'epsestimate': 1.46,
#   'epsactual': 1.66,
#   'epssurprisepct': 13.99,
#   'timeZoneShortName': 'EST',
#   'gmtOffsetMilliSeconds': 0,
#   'quoteType': 'EQUITY'},
#  {'ticker': 'AAPL',
#   'companyshortname': 'Apple Inc.',
#   'startdatetime': '2014-01-27T00:00:00.000Z',
#   'startdatetimetype': 'TNS',
#   'epsestimate': 2.01,
#   'epsactual': 2.07,
#   'epssurprisepct': 3.08,
#   'timeZoneShortName': 'EST',
#   'gmtOffsetMilliSeconds': 0,
#   'quoteType': 'EQUITY'},
#  {'ticker': 'AAPL',
#   'companyshortname': 'Apple Inc.',
#   'startdatetime': '2013-10-28T00:00:00.000Z',
#   'startdatetimetype': 'TNS',
#   'epsestimate': 1.14,
#   'epsactual': 1.18,
#   'epssurprisepct': 3.82,
#   'timeZoneShortName': 'EST',
#   'gmtOffsetMilliSeconds': 0,
#   'quoteType': 'EQUITY'},
#  {'ticker': 'AAPL',
#   'companyshortname': 'Apple Inc.',
#   'startdatetime': '2013-07-23T00:00:00.000Z',
#   'startdatetimetype': 'TNS',
#   'epsestimate': 1.05,
#   'epsactual': 1.07,
#   'epssurprisepct': 2.05,
#   'timeZoneShortName': 'EST',
#   'gmtOffsetMilliSeconds': 0,
#   'quoteType': 'EQUITY'},
#  {'ticker': 'AAPL',
#   'companyshortname': 'Apple Inc.',
#   'startdatetime': '2013-04-23T00:00:00.000Z',
#   'startdatetimetype': 'TNS',
#   'epsestimate': 1.43,
#   'epsactual': 1.44,
#   'epssurprisepct': 0.88,
#   'timeZoneShortName': 'EST',
#   'gmtOffsetMilliSeconds': 0,
#   'quoteType': 'EQUITY'},
#  {'ticker': 'AAPL',
#   'companyshortname': 'Apple Inc.',
#   'startdatetime': '2013-01-23T00:00:00.000Z',
#   'startdatetimetype': 'TNS',
#   'epsestimate': 1.92,
#   'epsactual': 1.97,
#   'epssurprisepct': 2.52,
#   'timeZoneShortName': 'EST',
#   'gmtOffsetMilliSeconds': 0,
#   'quoteType': 'EQUITY'},
#  {'ticker': 'AAPL',
#   'companyshortname': 'Apple Inc.',
#   'startdatetime': '2012-10-25T00:00:00.000Z',
#   'startdatetimetype': 'TNS',
#   'epsestimate': 1.25,
#   'epsactual': 1.24,
#   'epssurprisepct': -0.91,
#   'timeZoneShortName': 'EST',
#   'gmtOffsetMilliSeconds': 0,
#   'quoteType': 'EQUITY'},
#  {'ticker': 'AAPL',
#   'companyshortname': 'Apple Inc.',
#   'startdatetime': '2012-07-24T00:00:00.000Z',
#   'startdatetimetype': 'TNS',
#   'epsestimate': 1.48,
#   'epsactual': 1.33,
#   'epssurprisepct': -10.12,
#   'timeZoneShortName': 'EST',
#   'gmtOffsetMilliSeconds': 0,
#   'quoteType': 'EQUITY'},
#  {'ticker': 'AAPL',
#   'companyshortname': 'Apple Inc.',
#   'startdatetime': '2012-04-24T00:00:00.000Z',
#   'startdatetimetype': 'TNS',
#   'epsestimate': 1.43,
#   'epsactual': 1.76,
#   'epssurprisepct': 22.55,
#   'timeZoneShortName': 'EST',
#   'gmtOffsetMilliSeconds': 0,
#   'quoteType': 'EQUITY'},
#  {'ticker': 'AAPL',
#   'companyshortname': 'Apple Inc.',
#   'startdatetime': '2012-01-24T00:00:00.000Z',
#   'startdatetimetype': 'TNS',
#   'epsestimate': 1.45,
#   'epsactual': 1.98,
#   'epssurprisepct': 36.46,
#   'timeZoneShortName': 'EST',
#   'gmtOffsetMilliSeconds': 0,
#   'quoteType': 'EQUITY'},
#  {'ticker': 'AAPL',
#   'companyshortname': 'Apple Inc.',
#   'startdatetime': '2011-10-18T00:00:00.000Z',
#   'startdatetimetype': 'TNS',
#   'epsestimate': 1.06,
#   'epsactual': 1.01,
#   'epssurprisepct': -4.54,
#   'timeZoneShortName': 'EST',
#   'gmtOffsetMilliSeconds': 0,
#   'quoteType': 'EQUITY'},
#  {'ticker': 'AAPL',
#   'companyshortname': 'Apple Inc.',
#   'startdatetime': '2011-07-19T00:00:00.000Z',
#   'startdatetimetype': 'TNS',
#   'epsestimate': 0.83,
#   'epsactual': 1.11,
#   'epssurprisepct': 33.58,
#   'timeZoneShortName': 'EST',
#   'gmtOffsetMilliSeconds': 0,
#   'quoteType': 'EQUITY'},
#  {'ticker': 'AAPL',
#   'companyshortname': 'Apple Inc.',
#   'startdatetime': '2011-04-20T00:00:00.000Z',
#   'startdatetimetype': 'TNS',
#   'epsestimate': 0.77,
#   'epsactual': 0.91,
#   'epssurprisepct': 19.09,
#   'timeZoneShortName': 'EST',
#   'gmtOffsetMilliSeconds': 0,
#   'quoteType': 'EQUITY'},
#  {'ticker': 'AAPL',
#   'companyshortname': 'Apple Inc.',
#   'startdatetime': '2011-01-18T00:00:00.000Z',
#   'startdatetimetype': 'TNS',
#   'epsestimate': 0.77,
#   'epsactual': 0.92,
#   'epssurprisepct': 19.03,
#   'timeZoneShortName': 'EST',
#   'gmtOffsetMilliSeconds': 0,
#   'quoteType': 'EQUITY'},
#  {'ticker': 'AAPL',
#   'companyshortname': 'Apple Inc.',
#   'startdatetime': '2010-10-18T00:00:00.000Z',
#   'startdatetimetype': 'TNS',
#   'epsestimate': 0.58,
#   'epsactual': 0.66,
#   'epssurprisepct': 13.65,
#   'timeZoneShortName': 'EST',
#   'gmtOffsetMilliSeconds': 0,
#   'quoteType': 'EQUITY'},
#  {'ticker': 'AAPL',
#   'companyshortname': 'Apple Inc.',
#   'startdatetime': '2010-07-20T00:00:00.000Z',
#   'startdatetimetype': 'TNS',
#   'epsestimate': 0.44,
#   'epsactual': 0.5,
#   'epssurprisepct': 12.68,
#   'timeZoneShortName': 'EST',
#   'gmtOffsetMilliSeconds': 0,
#   'quoteType': 'EQUITY'},
#  {'ticker': 'AAPL',
#   'companyshortname': 'Apple Inc.',
#   'startdatetime': '2010-04-20T00:00:00.000Z',
#   'startdatetimetype': 'TNS',
#   'epsestimate': 0.35,
#   'epsactual': 0.48,
#   'epssurprisepct': 36.1,
#   'timeZoneShortName': 'EST',
#   'gmtOffsetMilliSeconds': 0,
#   'quoteType': 'EQUITY'},
#  {'ticker': 'AAPL',
#   'companyshortname': 'Apple Inc.',
#   'startdatetime': '2010-01-25T00:00:00.000Z',
#   'startdatetimetype': 'TNS',
#   'epsestimate': 0.3,
#   'epsactual': 0.52,
#   'epssurprisepct': 76,
#   'timeZoneShortName': 'EST',
#   'gmtOffsetMilliSeconds': 0,
#   'quoteType': 'EQUITY'},
#  {'ticker': 'AAPL',
#   'companyshortname': 'Apple Inc.',
#   'startdatetime': '2009-10-19T00:00:00.000Z',
#   'startdatetimetype': 'TNS',
#   'epsestimate': 0.2,
#   'epsactual': 0.26,
#   'epssurprisepct': 27.8,
#   'timeZoneShortName': 'EST',
#   'gmtOffsetMilliSeconds': 0,
#   'quoteType': 'EQUITY'},
#  {'ticker': 'AAPL',
#   'companyshortname': 'Apple Inc.',
#   'startdatetime': '2009-07-21T00:00:00.000Z',
#   'startdatetimetype': 'TNS',
#   'epsestimate': 0.17,
#   'epsactual': 0.19,
#   'epssurprisepct': 15.05,
#   'timeZoneShortName': 'EST',
#   'gmtOffsetMilliSeconds': 0,
#   'quoteType': 'EQUITY'},
#  {'ticker': 'AAPL',
#   'companyshortname': 'Apple Inc.',
#   'startdatetime': '2009-04-22T00:00:00.000Z',
#   'startdatetimetype': 'TNS',
#   'epsestimate': 0.16,
#   'epsactual': 0.19,
#   'epssurprisepct': 22.05,
#   'timeZoneShortName': 'EST',
#   'gmtOffsetMilliSeconds': 0,
#   'quoteType': 'EQUITY'},
#  {'ticker': 'AAPL',
#   'companyshortname': 'Apple Inc.',
#   'startdatetime': '2009-01-21T00:00:00.000Z',
#   'startdatetimetype': 'TNS',
#   'epsestimate': 0.2,
#   'epsactual': 0.25,
#   'epssurprisepct': 28.26,
#   'timeZoneShortName': 'EST',
#   'gmtOffsetMilliSeconds': 0,
#   'quoteType': 'EQUITY'},
#  {'ticker': 'AAPL',
#   'companyshortname': 'Apple Inc.',
#   'startdatetime': '2008-10-21T00:00:00.000Z',
#   'startdatetimetype': 'TNS',
#   'epsestimate': 0.16,
#   'epsactual': 0.18,
#   'epssurprisepct': 13.3,
#   'timeZoneShortName': 'EST',
#   'gmtOffsetMilliSeconds': 0,
#   'quoteType': 'EQUITY'},
#  {'ticker': 'AAPL',
#   'companyshortname': 'Apple Inc.',
#   'startdatetime': '2008-07-21T00:00:00.000Z',
#   'startdatetimetype': 'TNS',
#   'epsestimate': 0.15,
#   'epsactual': 0.17,
#   'epssurprisepct': 10.4,
#   'timeZoneShortName': 'EST',
#   'gmtOffsetMilliSeconds': 0,
#   'quoteType': 'EQUITY'},
#  {'ticker': 'AAPL',
#   'companyshortname': 'Apple Inc.',
#   'startdatetime': '2008-04-23T00:00:00.000Z',
#   'startdatetimetype': 'TNS',
#   'epsestimate': 0.15,
#   'epsactual': 0.17,
#   'epssurprisepct': 8.1,
#   'timeZoneShortName': 'EST',
#   'gmtOffsetMilliSeconds': 0,
#   'quoteType': 'EQUITY'},
#  {'ticker': 'AAPL',
#   'companyshortname': 'Apple Inc.',
#   'startdatetime': '2008-01-22T00:00:00.000Z',
#   'startdatetimetype': 'TNS',
#   'epsestimate': 0.23,
#   'epsactual': 0.25,
#   'epssurprisepct': 8.86,
#   'timeZoneShortName': 'EST',
#   'gmtOffsetMilliSeconds': 0,
#   'quoteType': 'EQUITY'},
#  {'ticker': 'AAPL',
#   'companyshortname': 'Apple Inc.',
#   'startdatetime': '2007-10-22T00:00:00.000Z',
#   'startdatetimetype': 'TNS',
#   'epsestimate': 0.12,
#   'epsactual': 0.14,
#   'epssurprisepct': 17.88,
#   'timeZoneShortName': 'EST',
#   'gmtOffsetMilliSeconds': 0,
#   'quoteType': 'EQUITY'},
#  {'ticker': 'AAPL',
#   'companyshortname': 'Apple Inc.',
#   'startdatetime': '2007-07-25T00:00:00.000Z',
#   'startdatetimetype': 'TNS',
#   'epsestimate': 0.1,
#   'epsactual': 0.13,
#   'epssurprisepct': 27.07,
#   'timeZoneShortName': 'EST',
#   'gmtOffsetMilliSeconds': 0,
#   'quoteType': 'EQUITY'},
#  {'ticker': 'AAPL',
#   'companyshortname': 'Apple Inc.',
#   'startdatetime': '2007-04-25T00:00:00.000Z',
#   'startdatetimetype': 'TNS',
#   'epsestimate': 0.09,
#   'epsactual': 0.12,
#   'epssurprisepct': 35.94,
#   'timeZoneShortName': 'EST',
#   'gmtOffsetMilliSeconds': 0,
#   'quoteType': 'EQUITY'},
#  {'ticker': 'AAPL',
#   'companyshortname': 'Apple Inc.',
#   'startdatetime': '2007-01-17T00:00:00.000Z',
#   'startdatetimetype': 'TNS',
#   'epsestimate': 0.11,
#   'epsactual': 0.16,
#   'epssurprisepct': 45.38,
#   'timeZoneShortName': 'EST',
#   'gmtOffsetMilliSeconds': 0,
#   'quoteType': 'EQUITY'},
#  {'ticker': 'AAPL',
#   'companyshortname': 'Apple Inc.',
#   'startdatetime': '2006-10-18T00:00:00.000Z',
#   'startdatetimetype': 'TNS',
#   'epsestimate': 0.07,
#   'epsactual': 0.09,
#   'epssurprisepct': 22.55,
#   'timeZoneShortName': 'EST',
#   'gmtOffsetMilliSeconds': 0,
#   'quoteType': 'EQUITY'},
#  {'ticker': 'AAPL',
#   'companyshortname': 'Apple Inc.',
#   'startdatetime': '2006-07-19T00:00:00.000Z',
#   'startdatetimetype': 'TNS',
#   'epsestimate': 0.06,
#   'epsactual': 0.08,
#   'epssurprisepct': 22.85,
#   'timeZoneShortName': 'EST',
#   'gmtOffsetMilliSeconds': 0,
#   'quoteType': 'EQUITY'},
#  {'ticker': 'AAPL',
#   'companyshortname': 'Apple Inc.',
#   'startdatetime': '2006-04-19T00:00:00.000Z',
#   'startdatetimetype': 'TNS',
#   'epsestimate': 0.06,
#   'epsactual': 0.07,
#   'epssurprisepct': 8.22,
#   'timeZoneShortName': 'EST',
#   'gmtOffsetMilliSeconds': 0,
#   'quoteType': 'EQUITY'},
#  {'ticker': 'AAPL',
#   'companyshortname': 'Apple Inc.',
#   'startdatetime': '2006-01-18T00:00:00.000Z',
#   'startdatetimetype': 'TNS',
#   'epsestimate': 0.09,
#   'epsactual': 0.09,
#   'epssurprisepct': 7.09,
#   'timeZoneShortName': 'EST',
#   'gmtOffsetMilliSeconds': 0,
#   'quoteType': 'EQUITY'},
#  {'ticker': 'AAPL',
#   'companyshortname': 'Apple Inc.',
#   'startdatetime': '2005-10-11T00:00:00.000Z',
#   'startdatetimetype': 'TNS',
#   'epsestimate': 0.05,
#   'epsactual': 0.05,
#   'epssurprisepct': 2.16,
#   'timeZoneShortName': 'EST',
#   'gmtOffsetMilliSeconds': 0,
#   'quoteType': 'EQUITY'},
#  {'ticker': 'AAPL',
#   'companyshortname': 'Apple Inc.',
#   'startdatetime': '2005-07-13T00:00:00.000Z',
#   'startdatetimetype': 'TNS',
#   'epsestimate': 0.04,
#   'epsactual': 0.05,
#   'epssurprisepct': 17.96,
#   'timeZoneShortName': 'EST',
#   'gmtOffsetMilliSeconds': 0,
#   'quoteType': 'EQUITY'},
#  {'ticker': 'AAPL',
#   'companyshortname': 'Apple Inc.',
#   'startdatetime': '2005-04-13T00:00:00.000Z',
#   'startdatetimetype': 'TNS',
#   'epsestimate': 0.03,
#   'epsactual': 0.05,
#   'epssurprisepct': 39.69,
#   'timeZoneShortName': 'EST',
#   'gmtOffsetMilliSeconds': 0,
#   'quoteType': 'EQUITY'},
#  {'ticker': 'AAPL',
#   'companyshortname': 'Apple Inc.',
#   'startdatetime': '2005-01-12T00:00:00.000Z',
#   'startdatetimetype': 'TNS',
#   'epsestimate': 0.03,
#   'epsactual': 0.05,
#   'epssurprisepct': 43.93,
#   'timeZoneShortName': 'EST',
#   'gmtOffsetMilliSeconds': 0,
#   'quoteType': 'EQUITY'},
#  {'ticker': 'AAPL',
#   'companyshortname': 'Apple Inc.',
#   'startdatetime': '2004-10-13T00:00:00.000Z',
#   'startdatetimetype': 'TNS',
#   'epsestimate': 0.01,
#   'epsactual': 0.02,
#   'epssurprisepct': 47.7,
#   'timeZoneShortName': 'EST',
#   'gmtOffsetMilliSeconds': 0,
#   'quoteType': 'EQUITY'},
#  {'ticker': 'AAPL',
#   'companyshortname': 'Apple Inc.',
#   'startdatetime': '2004-07-14T00:00:00.000Z',
#   'startdatetimetype': 'TNS',
#   'epsestimate': 0.01,
#   'epsactual': 0.01,
#   'epssurprisepct': 14.96,
#   'timeZoneShortName': 'EST',
#   'gmtOffsetMilliSeconds': 0,
#   'quoteType': 'EQUITY'},
#  {'ticker': 'AAPL',
#   'companyshortname': 'Apple Inc.',
#   'startdatetime': '2004-04-14T00:00:00.000Z',
#   'startdatetimetype': 'TNS',
#   'epsestimate': 0.01,
#   'epsactual': 0.01,
#   'epssurprisepct': 46.41,
#   'timeZoneShortName': 'EST',
#   'gmtOffsetMilliSeconds': 0,
#   'quoteType': 'EQUITY'},
#  {'ticker': 'AAPL',
#   'companyshortname': 'Apple Inc.',
#   'startdatetime': '2004-01-14T00:00:00.000Z',
#   'startdatetimetype': 'TNS',
#   'epsestimate': 0.01,
#   'epsactual': 0.01,
#   'epssurprisepct': 9.38,
#   'timeZoneShortName': 'EST',
#   'gmtOffsetMilliSeconds': 0,
#   'quoteType': 'EQUITY'},
#  {'ticker': 'AAPL',
#   'companyshortname': 'Apple Inc.',
#   'startdatetime': '2003-10-15T00:00:00.000Z',
#   'startdatetimetype': 'TNS',
#   'epsestimate': 0,
#   'epsactual': 0.01,
#   'epssurprisepct': 20.46,
#   'timeZoneShortName': 'EST',
#   'gmtOffsetMilliSeconds': 0,
#   'quoteType': 'EQUITY'},
#  {'ticker': 'AAPL',
#   'companyshortname': 'Apple Inc.',
#   'startdatetime': '2003-07-16T00:00:00.000Z',
#   'startdatetimetype': 'TNS',
#   'epsestimate': 0,
#   'epsactual': 0,
#   'epssurprisepct': 63.01,
#   'timeZoneShortName': 'EST',
#   'gmtOffsetMilliSeconds': 0,
#   'quoteType': 'EQUITY'},
#  {'ticker': 'AAPL',
#   'companyshortname': 'Apple Inc.',
#   'startdatetime': '2003-04-16T00:00:00.000Z',
#   'startdatetimetype': 'TNS',
#   'epsestimate': 0,
#   'epsactual': 0,
#   'epssurprisepct': 100,
#   'timeZoneShortName': 'EST',
#   'gmtOffsetMilliSeconds': 0,
#   'quoteType': 'EQUITY'},
#  {'ticker': 'AAPL',
#   'companyshortname': 'Apple Inc.',
#   'startdatetime': '2003-01-15T00:00:00.000Z',
#   'startdatetimetype': 'TNS',
#   'epsestimate': 0,
#   'epsactual': 0,
#   'epssurprisepct': -47.8,
#   'timeZoneShortName': 'EST',
#   'gmtOffsetMilliSeconds': 0,
#   'quoteType': 'EQUITY'},
#  {'ticker': 'AAPL',
#   'companyshortname': 'Apple Inc.',
#   'startdatetime': '2002-10-16T00:00:00.000Z',
#   'startdatetimetype': 'TNS',
#   'epsestimate': 0,
#   'epsactual': 0,
#   'epssurprisepct': -66.9,
#   'timeZoneShortName': 'EST',
#   'gmtOffsetMilliSeconds': 0,
#   'quoteType': 'EQUITY'},
#  {'ticker': 'AAPL',
#   'companyshortname': 'Apple Inc.',
#   'startdatetime': '2002-07-16T00:00:00.000Z',
#   'startdatetimetype': 'TNS',
#   'epsestimate': 0.01,
#   'epsactual': 0.01,
#   'epssurprisepct': 3.04,
#   'timeZoneShortName': 'EST',
#   'gmtOffsetMilliSeconds': 0,
#   'quoteType': 'EQUITY'},
#  {'ticker': 'AAPL',
#   'companyshortname': 'Apple Inc.',
#   'startdatetime': '2002-01-16T00:00:00.000Z',
#   'startdatetimetype': 'TNS',
#   'epsestimate': 0.01,
#   'epsactual': 0.01,
#   'epssurprisepct': 2.21,
#   'timeZoneShortName': 'EST',
#   'gmtOffsetMilliSeconds': 0,
#   'quoteType': 'EQUITY'},
#  {'ticker': 'AAPL',
#   'companyshortname': 'Apple Inc.',
#   'startdatetime': '2001-04-18T00:00:00.000Z',
#   'startdatetimetype': 'TNS',
#   'epsestimate': 0,
#   'epsactual': 0.01,
#   'epssurprisepct': 920.78,
#   'timeZoneShortName': 'EST',
#   'gmtOffsetMilliSeconds': 0,
#   'quoteType': 'EQUITY'},
#  {'ticker': 'AAPL',
#   'companyshortname': 'Apple Inc.',
#   'startdatetime': '2000-10-18T00:00:00.000Z',
#   'startdatetimetype': 'TNS',
#   'epsestimate': 0.01,
#   'epsactual': 0.01,
#   'epssurprisepct': -3.94,
#   'timeZoneShortName': 'EST',
#   'gmtOffsetMilliSeconds': 0,
#   'quoteType': 'EQUITY'},
#  {'ticker': 'AAPL',
#   'companyshortname': 'Apple Inc.',
#   'startdatetime': '2000-07-18T00:00:00.000Z',
#   'startdatetimetype': 'TNS',
#   'epsestimate': 0.03,
#   'epsactual': 0.03,
#   'epssurprisepct': 3.01,
#   'timeZoneShortName': 'EST',
#   'gmtOffsetMilliSeconds': 0,
#   'quoteType': 'EQUITY'},
#  {'ticker': 'AAPL',
#   'companyshortname': 'Apple Inc.',
#   'startdatetime': '2000-04-19T00:00:00.000Z',
#   'startdatetimetype': 'TNS',
#   'epsestimate': 0.03,
#   'epsactual': 0.03,
#   'epssurprisepct': 9.59,
#   'timeZoneShortName': 'EST',
#   'gmtOffsetMilliSeconds': 0,
#   'quoteType': 'EQUITY'},
#  {'ticker': 'AAPL',
#   'companyshortname': 'Apple Inc.',
#   'startdatetime': '2000-01-19T00:00:00.000Z',
#   'startdatetimetype': 'TNS',
#   'epsestimate': 0.03,
#   'epsactual': 0.04,
#   'epssurprisepct': 11.14,
#   'timeZoneShortName': 'EST',
#   'gmtOffsetMilliSeconds': 0,
#   'quoteType': 'EQUITY'},
#  {'ticker': 'AAPL',
#   'companyshortname': 'Apple Inc.',
#   'startdatetime': '1999-10-13T00:00:00.000Z',
#   'startdatetimetype': 'TNS',
#   'epsestimate': 0.02,
#   'epsactual': 0.02,
#   'epssurprisepct': 12.69,
#   'timeZoneShortName': 'EST',
#   'gmtOffsetMilliSeconds': 0,
#   'quoteType': 'EQUITY'},
#  {'ticker': 'AAPL',
#   'companyshortname': 'Apple Inc.',
#   'startdatetime': '1999-07-14T00:00:00.000Z',
#   'startdatetimetype': 'TNS',
#   'epsestimate': 0.02,
#   'epsactual': 0.02,
#   'epssurprisepct': 7.69,
#   'timeZoneShortName': 'EST',
#   'gmtOffsetMilliSeconds': 0,
#   'quoteType': 'EQUITY'},
#  {'ticker': 'AAPL',
#   'companyshortname': 'Apple Inc.',
#   'startdatetime': '1999-04-14T00:00:00.000Z',
#   'startdatetimetype': 'TNS',
#   'epsestimate': 0.02,
#   'epsactual': 0.02,
#   'epssurprisepct': 19.24,
#   'timeZoneShortName': 'EST',
#   'gmtOffsetMilliSeconds': 0,
#   'quoteType': 'EQUITY'},
#  {'ticker': 'AAPL',
#   'companyshortname': 'Apple Inc.',
#   'startdatetime': '1999-01-13T00:00:00.000Z',
#   'startdatetimetype': 'TNS',
#   'epsestimate': 0.02,
#   'epsactual': 0.03,
#   'epssurprisepct': 12.79,
#   'timeZoneShortName': 'EST',
#   'gmtOffsetMilliSeconds': 0,
#   'quoteType': 'EQUITY'},
#  {'ticker': 'AAPL',
#   'companyshortname': 'Apple Inc.',
#   'startdatetime': '1998-10-14T00:00:00.000Z',
#   'startdatetimetype': 'TNS',
#   'epsestimate': 0.02,
#   'epsactual': 0.02,
#   'epssurprisepct': 39.92,
#   'timeZoneShortName': 'EST',
#   'gmtOffsetMilliSeconds': 0,
#   'quoteType': 'EQUITY'},
#  {'ticker': 'AAPL',
#   'companyshortname': 'Apple Inc.',
#   'startdatetime': '1998-07-15T00:00:00.000Z',
#   'startdatetimetype': 'TNS',
#   'epsestimate': 0.01,
#   'epsactual': 0.02,
#   'epssurprisepct': 68.49,
#   'timeZoneShortName': 'EST',
#   'gmtOffsetMilliSeconds': 0,
#   'quoteType': 'EQUITY'},
#  {'ticker': 'AAPL',
#   'companyshortname': 'Apple Inc.',
#   'startdatetime': '1998-04-15T00:00:00.000Z',
#   'startdatetimetype': 'TNS',
#   'epsestimate': 0.01,
#   'epsactual': 0.01,
#   'epssurprisepct': 156.52,
#   'timeZoneShortName': 'EST',
#   'gmtOffsetMilliSeconds': 0,
#   'quoteType': 'EQUITY'},
#  {'ticker': 'AAPL',
#   'companyshortname': 'Apple Inc.',
#   'startdatetime': '1998-01-14T00:00:00.000Z',
#   'startdatetimetype': 'TNS',
#   'epsestimate': 0.01,
#   'epsactual': 0.01,
#   'epssurprisepct': 22.3,
#   'timeZoneShortName': 'EST',
#   'gmtOffsetMilliSeconds': 0,
#   'quoteType': 'EQUITY'},
#  {'ticker': 'AAPL',
#   'companyshortname': 'Apple Inc.',
#   'startdatetime': '1997-10-15T00:00:00.000Z',
#   'startdatetimetype': 'TNS',
#   'epsestimate': 0,
#   'epsactual': 0,
#   'epssurprisepct': -50.44,
#   'timeZoneShortName': 'EST',
#   'gmtOffsetMilliSeconds': 0,
#   'quoteType': 'EQUITY'},
#  {'ticker': 'AAPL',
#   'companyshortname': 'Apple Inc.',
#   'startdatetime': '1997-07-16T00:00:00.000Z',
#   'startdatetimetype': 'TNS',
#   'epsestimate': -0.02,
#   'epsactual': -0.02,
#   'epssurprisepct': 26.79,
#   'timeZoneShortName': 'EST',
#   'gmtOffsetMilliSeconds': 0,
#   'quoteType': 'EQUITY'},
#  {'ticker': 'AAPL',
#   'companyshortname': 'Apple Inc.',
#   'startdatetime': '1997-04-16T00:00:00.000Z',
#   'startdatetimetype': 'TNS',
#   'epsestimate': -0.04,
#   'epsactual': -0.05,
#   'epssurprisepct': -18.29,
#   'timeZoneShortName': 'EST',
#   'gmtOffsetMilliSeconds': 0,
#   'quoteType': 'EQUITY'},
#  {'ticker': 'AAPL',
#   'companyshortname': 'Apple Inc.',
#   'startdatetime': '1997-01-15T00:00:00.000Z',
#   'startdatetimetype': 'TNS',
#   'epsestimate': -0.02,
#   'epsactual': -0.03,
#   'epssurprisepct': -48.31,
#   'timeZoneShortName': 'EST',
#   'gmtOffsetMilliSeconds': 0,
#   'quoteType': 'EQUITY'}]
